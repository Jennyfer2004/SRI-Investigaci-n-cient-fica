# %% [markdown]
# Preprocesamiento de los artículos

# %%
import os
import pandas as pd

OUTPUT_FILE = "/home/jennifer/Descargas/papers_guardados-2.csv"

if os.path.exists(OUTPUT_FILE):
    df_existente = pd.read_csv(OUTPUT_FILE)

    df_limpio = df_existente[df_existente['contenido'].notna() & (df_existente['contenido'] != '')]
    df_limpio.to_csv(OUTPUT_FILE, index=False)

    print(f"Archivo limpiado guardado.: {len(df_limpio)}")
    print(f"Archivo limpiado guardado.: {len(df_existente)}")
# Out:
# Archivo limpiado guardado.: 865
# Archivo limpiado guardado.: 865

# %%
import pandas as pd

df = pd.read_csv('/home/jennifer/Documentos/tercer_año/segundo_semestre/SRI/proyecto final/papers_guardados.csv')  
df1=pd.read_csv("/home/jennifer/Descargas/papers_guardados-2.csv")  

# Concatenar df y df1 fila a fila 
df = pd.concat([df, df1], axis=0, ignore_index=True)
print(df.columns,len(df))
# Out:
# Index(['title', 'doi', 'landing_page', 'authors', 'published', 'abstract',
#        'language', 'pdf_url', 'contenido'],
#       dtype='object') 2865

# %%
import pandas as pd
import re
from langchain_core.documents import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

def normalize_text(text):
    """ 
    Normaliza un texto eliminando caracteres especiales y estandarizando formatos.
    Args:
        text(str): Texto sin procesar
    Return:
        str: Texto preprocesado para caracteres especiales.
    """
    if type(text)==float:
        print(text)
    text = text.lower()
    text = re.sub(r"[^a-záéíóúüñ\s]", "", text)
    text = text.replace('“', '"').replace('”', '"')
    text = text.replace("’", "'").replace("–", "-").replace("—", "-")
    text = re.sub(r'\s+', ' ', text)
    return text
urls=[]
count=0
def remove_sections(text):
    """    
    Elimina secciones específicas del contenido del artículo como Referencias y Agradecimientos, así como todo lo que contenga después 
    Args:
        text(str): Contenido del artículo para eliminar secciones
    Return:    
        str: El texto anterior eliminando las secciones anteriores
    """
    global count
    count+=1
    after_refs = re.split(r'\n(references|bibliography|acknowledg(e)?ments)\b', text, flags=re.IGNORECASE)  

    return after_refs[0]


def clean_text(text):
    """
    Realiza limpieza del texto eliminando caracteres invisibles y espacios múltiples.
    Args:
        text (str): Texto a limpiar.
    Return:    
        str: Texto limpio con espaciado uniforme

    """
   
    if not isinstance(text, str): 
        return ""
    text = re.sub(r'[\x00-\x08\x0B-\x0C\x0E-\x1F\x7F]', ' ', text)
    text = re.sub(r'[ \t]+', ' ', text)
    return text.strip()

df['clean_abstract'] = df['abstract'].apply(clean_text)
df['clean_title'] = df['title'].apply(clean_text)
df['clean_contenido']=df['contenido'].apply(remove_sections)
df['clean_contenido'] = df['clean_contenido'].apply(normalize_text)
df['clean_contenido'] = df['clean_contenido'].apply(clean_text)
df = df[df['clean_contenido'].str.len() > 200]

# %% [markdown]
# Combirtiendo a embedings los artículos

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
import time

print(f"[{time.strftime('%H:%M:%S')}] INFO: Convirtiendo DataFrame a Documentos LangChain...")
documents = []
for _, row in df.iterrows():
    content = f"{row['clean_abstract']}\n\n{row['clean_contenido']}"
    
    metadata = {
        'titulo': row['clean_title'], 
        'doi': row['doi'],
        'autores': row['authors'],
        'publicado': row['published'],
        'idioma': row['language'],
        'url_pdf': row['pdf_url'],
        'url_landing': row['landing_page'],
    }
    
    documents.append(Document(page_content=content, metadata=metadata))
print(f"[{time.strftime('%H:%M:%S')}] INFO: {len(documents)} documentos creados.")


print(f"[{time.strftime('%H:%M:%S')}] INFO: Iniciando división de documentos en chunks...")
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1200, 
    chunk_overlap=200, 
    separators=["\n\n", "\n", r"(?<=\. )", " "],  # Respetar estructura
    length_function=len,
    is_separator_regex=True
)

chunks = []
for i, doc in enumerate(documents):
    splits = text_splitter.split_documents([doc])
    for j, split in enumerate(splits):
        split.metadata['fragmento_id'] = f"{doc.metadata['doi']}_part{j+1}"
    chunks.extend(splits)
    print(f"[{time.strftime('%H:%M:%S')}] DEBUG: Documento {i+1} dividido en {len(splits)} fragmentos.")

print(f"[{time.strftime('%H:%M:%S')}] INFO: Total de {len(chunks)} fragmentos creados.")

print(f"[{time.strftime('%H:%M:%S')}] INFO: Cargando modelo de embeddings HuggingFace...")
embed_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2", encode_kwargs={'normalize_embeddings': True}
)
print(f"[{time.strftime('%H:%M:%S')}] INFO: Modelo de embeddings cargado correctamente.")


print(f"[{time.strftime('%H:%M:%S')}] INFO: Creando base vectorial con ChromaDB...")
vector_db = Chroma.from_documents(
    documents=chunks,
    embedding=embed_model,
    persist_directory="./repositorio_vectorial",
    collection_metadata={"hnsw:space": "cosine"}  # Optimizado para similitud
)

print(f"[{time.strftime('%H:%M:%S')}] INFO: Guardado base vectorial en disco...")
#vector_db.persist()
# Out:
# [19:19:45] INFO: Convirtiendo DataFrame a Documentos LangChain...
# [19:19:45] INFO: 2835 documentos creados.
# [19:19:45] INFO: Iniciando división de documentos en chunks...
# [19:19:45] DEBUG: Documento 1 dividido en 17 fragmentos.
# [19:19:45] DEBUG: Documento 2 dividido en 22 fragmentos.
# [19:19:45] DEBUG: Documento 3 dividido en 22 fragmentos.
# [19:19:45] DEBUG: Documento 4 dividido en 4 fragmentos.
# [19:19:45] DEBUG: Documento 5 dividido en 6 fragmentos.
# [19:19:45] DEBUG: Documento 6 dividido en 15 fragmentos.
# [19:19:45] DEBUG: Documento 7 dividido en 33 fragmentos.
# [19:19:45] DEBUG: Documento 8 dividido en 19 fragmentos.
# [19:19:45] DEBUG: Documento 9 dividido en 16 fragmentos.
# [19:19:45] DEBUG: Documento 10 dividido en 23 fragmentos.
# [19:19:45] DEBUG: Documento 11 dividido en 21 fragmentos.
# [19:19:45] DEBUG: Documento 12 dividido en 25 fragmentos.
# [19:19:45] DEBUG: Documento 13 dividido en 15 fragmentos.
# [19:19:45] DEBUG: Documento 14 dividido en 20 fragmentos.
# [19:19:45] DEBUG: Documento 15 dividido en 16 fragmentos.
# [19:19:45] DEBUG: Documento 16 dividido en 17 fragmentos.
# [19:19:45] DEBUG: Documento 17 dividido en 16 fragmentos.
# [19:19:45] DEBUG: Documento 18 dividido en 13 fragmentos.
# [19:19:45] DEBUG: Documento 19 dividido en 43 fragmentos.
# [19:19:45] DEBUG: Documento 20 dividido en 94 fragmentos.
# [19:19:45] DEBUG: Documento 21 dividido en 16 fragmentos.
# [19:19:45] DEBUG: Documento 22 dividido en 6 fragmentos.
# [19:19:45] DEBUG: Documento 23 dividido en 3 fragmentos.
# [19:19:45] DEBUG: Documento 24 dividido en 44 fragmentos.
# [19:19:45] DEBUG: Documento 25 dividido en 12 fragmentos.
# [19:19:45] DEBUG: Documento 26 dividido en 42 fragmentos.
# [19:19:45] DEBUG: Documento 27 dividido en 37 fragmentos.
# [19:19:45] DEBUG: Documento 28 dividido en 35 fragmentos.
# [19:19:45] DEBUG: Documento 29 dividido en 14 fragmentos.
# [19:19:45] DEBUG: Documento 30 dividido en 17 fragmentos.
# [19:19:45] DEBUG: Documento 31 dividido en 51 fragmentos.
# [19:19:45] DEBUG: Documento 32 dividido en 45 fragmentos.
# [19:19:45] DEBUG: Documento 33 dividido en 26 fragmentos.
# [19:19:45] DEBUG: Documento 34 dividido en 20 fragmentos.
# [19:19:45] DEBUG: Documento 35 dividido en 13 fragmentos.
# [19:19:45] DEBUG: Documento 36 dividido en 27 fragmentos.
# [19:19:45] DEBUG: Documento 37 dividido en 10 fragmentos.
# [19:19:45] DEBUG: Documento 38 dividido en 10 fragmentos.
# [19:19:45] DEBUG: Documento 39 dividido en 55 fragmentos.
# [19:19:45] DEBUG: Documento 40 dividido en 21 fragmentos.
# [19:19:45] DEBUG: Documento 41 dividido en 79 fragmentos.
# [19:19:45] DEBUG: Documento 42 dividido en 3 fragmentos.
# [19:19:45] DEBUG: Documento 43 dividido en 4 fragmentos.
# [19:19:45] DEBUG: Documento 44 dividido en 34 fragmentos.
# [19:19:45] DEBUG: Documento 45 dividido en 5 fragmentos.
# [19:19:45] DEBUG: Documento 46 dividido en 4 fragmentos.
# [19:19:45] DEBUG: Documento 47 dividido en 2 fragmentos.
# [19:19:45] DEBUG: Documento 48 dividido en 172 fragmentos.
# [19:19:45] DEBUG: Documento 49 dividido en 3 fragmentos.
# [19:19:45] DEBUG: Documento 50 dividido en 2 fragmentos.
# [19:19:45] DEBUG: Documento 51 dividido en 4 fragmentos.
# [19:19:45] DEBUG: Documento 52 dividido en 5 fragmentos.
# [19:19:46] DEBUG: Documento 53 dividido en 403 fragmentos.
# [19:19:46] DEBUG: Documento 54 dividido en 4 fragmentos.
# [19:19:46] DEBUG: Documento 55 dividido en 1 fragmentos.
# [19:19:46] DEBUG: Documento 56 dividido en 5 fragmentos.
# [19:19:46] DEBUG: Documento 57 dividido en 197 fragmentos.
# [19:19:46] DEBUG: Documento 58 dividido en 6 fragmentos.
# [19:19:46] DEBUG: Documento 59 dividido en 22 fragmentos.
# [19:19:46] DEBUG: Documento 60 dividido en 4 fragmentos.
# [19:19:46] DEBUG: Documento 61 dividido en 160 fragmentos.
# [19:19:46] DEBUG: Documento 62 dividido en 5 fragmentos.
# [19:19:46] DEBUG: Documento 63 dividido en 26 fragmentos.
# [19:19:46] DEBUG: Documento 64 dividido en 5 fragmentos.
# [19:19:46] DEBUG: Documento 65 dividido en 6 fragmentos.
# [19:19:46] DEBUG: Documento 66 dividido en 4 fragmentos.
# [19:19:46] DEBUG: Documento 67 dividido en 6 fragmentos.
# [19:19:46] DEBUG: Documento 68 dividido en 3 fragmentos.
# [19:19:46] DEBUG: Documento 69 dividido en 4 fragmentos.
# [19:19:46] DEBUG: Documento 70 dividido en 3 fragmentos.
# [19:19:46] DEBUG: Documento 71 dividido en 54 fragmentos.
# [19:19:46] DEBUG: Documento 72 dividido en 6 fragmentos.
# [19:19:46] DEBUG: Documento 73 dividido en 34 fragmentos.
# [19:19:46] DEBUG: Documento 74 dividido en 4 fragmentos.
# [19:19:46] DEBUG: Documento 75 dividido en 11 fragmentos.
# [19:19:46] DEBUG: Documento 76 dividido en 35 fragmentos.
# [19:19:46] DEBUG: Documento 77 dividido en 7 fragmentos.
# [19:19:46] DEBUG: Documento 78 dividido en 46 fragmentos.
# [19:19:46] DEBUG: Documento 79 dividido en 82 fragmentos.
# [19:19:46] DEBUG: Documento 80 dividido en 66 fragmentos.
# [19:19:46] DEBUG: Documento 81 dividido en 5 fragmentos.
# [19:19:46] DEBUG: Documento 82 dividido en 3 fragmentos.
# [19:19:46] DEBUG: Documento 83 dividido en 25 fragmentos.
# [19:19:46] DEBUG: Documento 84 dividido en 41 fragmentos.
# [19:19:46] DEBUG: Documento 85 dividido en 5 fragmentos.
# [19:19:46] DEBUG: Documento 86 dividido en 3 fragmentos.
# [19:19:46] DEBUG: Documento 87 dividido en 16 fragmentos.
# [19:19:46] DEBUG: Documento 88 dividido en 4 fragmentos.
# [19:19:46] DEBUG: Documento 89 dividido en 72 fragmentos.
# [19:19:46] DEBUG: Documento 90 dividido en 58 fragmentos.
# [19:19:46] DEBUG: Documento 91 dividido en 75 fragmentos.
# [19:19:46] DEBUG: Documento 92 dividido en 47 fragmentos.
# [19:19:46] DEBUG: Documento 93 dividido en 10 fragmentos.
# [19:19:46] DEBUG: Documento 94 dividido en 3 fragmentos.
# [19:19:46] DEBUG: Documento 95 dividido en 25 fragmentos.
# [19:19:46] DEBUG: Documento 96 dividido en 114 fragmentos.
# [19:19:46] DEBUG: Documento 97 dividido en 40 fragmentos.
# [19:19:46] DEBUG: Documento 98 dividido en 27 fragmentos.
# [19:19:46] DEBUG: Documento 99 dividido en 14 fragmentos.
# [19:19:46] DEBUG: Documento 100 dividido en 10 fragmentos.
# [19:19:46] DEBUG: Documento 101 dividido en 24 fragmentos.
# [19:19:46] DEBUG: Documento 102 dividido en 4 fragmentos.
# [19:19:46] DEBUG: Documento 103 dividido en 46 fragmentos.
# [19:19:46] DEBUG: Documento 104 dividido en 14 fragmentos.
# [19:19:46] DEBUG: Documento 105 dividido en 5 fragmentos.
# [19:19:46] DEBUG: Documento 106 dividido en 59 fragmentos.
# [19:19:46] DEBUG: Documento 107 dividido en 39 fragmentos.
# [19:19:46] DEBUG: Documento 108 dividido en 9 fragmentos.
# [19:19:46] DEBUG: Documento 109 dividido en 5 fragmentos.
# [19:19:46] DEBUG: Documento 110 dividido en 17 fragmentos.
# [19:19:46] DEBUG: Documento 111 dividido en 83 fragmentos.
# [19:19:46] DEBUG: Documento 112 dividido en 15 fragmentos.
# [19:19:46] DEBUG: Documento 113 dividido en 12 fragmentos.
# [19:19:46] DEBUG: Documento 114 dividido en 9 fragmentos.
# [19:19:46] DEBUG: Documento 115 dividido en 13 fragmentos.
# [19:19:46] DEBUG: Documento 116 dividido en 9 fragmentos.
# [19:19:46] DEBUG: Documento 117 dividido en 65 fragmentos.
# [19:19:46] DEBUG: Documento 118 dividido en 4 fragmentos.
# [19:19:46] DEBUG: Documento 119 dividido en 8 fragmentos.
# [19:19:46] DEBUG: Documento 120 dividido en 40 fragmentos.
# [19:19:46] DEBUG: Documento 121 dividido en 58 fragmentos.
# [19:19:46] DEBUG: Documento 122 dividido en 30 fragmentos.
# [19:19:46] DEBUG: Documento 123 dividido en 4 fragmentos.
# [19:19:46] DEBUG: Documento 124 dividido en 22 fragmentos.
# [19:19:46] DEBUG: Documento 125 dividido en 2 fragmentos.
# [19:19:46] DEBUG: Documento 126 dividido en 32 fragmentos.
# [19:19:46] DEBUG: Documento 127 dividido en 33 fragmentos.
# [19:19:46] DEBUG: Documento 128 dividido en 2 fragmentos.
# [19:19:46] DEBUG: Documento 129 dividido en 13 fragmentos.
# [19:19:46] DEBUG: Documento 130 dividido en 27 fragmentos.
# [19:19:46] DEBUG: Documento 131 dividido en 4 fragmentos.
# [19:19:46] DEBUG: Documento 132 dividido en 66 fragmentos.
# [19:19:46] DEBUG: Documento 133 dividido en 11 fragmentos.
# [19:19:46] DEBUG: Documento 134 dividido en 48 fragmentos.
# [19:19:46] DEBUG: Documento 135 dividido en 49 fragmentos.
# [19:19:46] DEBUG: Documento 136 dividido en 12 fragmentos.
# [19:19:46] DEBUG: Documento 137 dividido en 27 fragmentos.
# [19:19:46] DEBUG: Documento 138 dividido en 29 fragmentos.
# [19:19:46] DEBUG: Documento 139 dividido en 3 fragmentos.
# [19:19:46] DEBUG: Documento 140 dividido en 43 fragmentos.
# [19:19:46] DEBUG: Documento 141 dividido en 5 fragmentos.
# [19:19:46] DEBUG: Documento 142 dividido en 49 fragmentos.
# [19:19:46] DEBUG: Documento 143 dividido en 29 fragmentos.
# [19:19:46] DEBUG: Documento 144 dividido en 29 fragmentos.
# [19:19:46] DEBUG: Documento 145 dividido en 9 fragmentos.
# [19:19:46] DEBUG: Documento 146 dividido en 10 fragmentos.
# [19:19:46] DEBUG: Documento 147 dividido en 21 fragmentos.
# [19:19:46] DEBUG: Documento 148 dividido en 17 fragmentos.
# [19:19:46] DEBUG: Documento 149 dividido en 64 fragmentos.
# [19:19:46] DEBUG: Documento 150 dividido en 17 fragmentos.
# [19:19:46] DEBUG: Documento 151 dividido en 30 fragmentos.
# [19:19:46] DEBUG: Documento 152 dividido en 36 fragmentos.
# [19:19:46] DEBUG: Documento 153 dividido en 13 fragmentos.
# [19:19:46] DEBUG: Documento 154 dividido en 23 fragmentos.
# [19:19:46] DEBUG: Documento 155 dividido en 43 fragmentos.
# [19:19:46] DEBUG: Documento 156 dividido en 48 fragmentos.
# [19:19:46] DEBUG: Documento 157 dividido en 13 fragmentos.
# [19:19:46] DEBUG: Documento 158 dividido en 3 fragmentos.
# [19:19:46] DEBUG: Documento 159 dividido en 46 fragmentos.
# [19:19:46] DEBUG: Documento 160 dividido en 3 fragmentos.
# [19:19:46] DEBUG: Documento 161 dividido en 35 fragmentos.
# [19:19:46] DEBUG: Documento 162 dividido en 91 fragmentos.
# [19:19:46] DEBUG: Documento 163 dividido en 32 fragmentos.
# [19:19:46] DEBUG: Documento 164 dividido en 26 fragmentos.
# [19:19:46] DEBUG: Documento 165 dividido en 32 fragmentos.
# [19:19:46] DEBUG: Documento 166 dividido en 38 fragmentos.
# [19:19:46] DEBUG: Documento 167 dividido en 19 fragmentos.
# [19:19:46] DEBUG: Documento 168 dividido en 42 fragmentos.
# [19:19:46] DEBUG: Documento 169 dividido en 72 fragmentos.
# [19:19:46] DEBUG: Documento 170 dividido en 28 fragmentos.
# [19:19:46] DEBUG: Documento 171 dividido en 8 fragmentos.
# [19:19:46] DEBUG: Documento 172 dividido en 56 fragmentos.
# [19:19:47] DEBUG: Documento 173 dividido en 85 fragmentos.
# [19:19:47] DEBUG: Documento 174 dividido en 8 fragmentos.
# [19:19:47] DEBUG: Documento 175 dividido en 1 fragmentos.
# [19:19:47] DEBUG: Documento 176 dividido en 20 fragmentos.
# [19:19:47] DEBUG: Documento 177 dividido en 53 fragmentos.
# [19:19:47] DEBUG: Documento 178 dividido en 13 fragmentos.
# [19:19:47] DEBUG: Documento 179 dividido en 10 fragmentos.
# [19:19:47] DEBUG: Documento 180 dividido en 37 fragmentos.
# [19:19:47] DEBUG: Documento 181 dividido en 23 fragmentos.
# [19:19:47] DEBUG: Documento 182 dividido en 61 fragmentos.
# [19:19:47] DEBUG: Documento 183 dividido en 3 fragmentos.
# [19:19:47] DEBUG: Documento 184 dividido en 31 fragmentos.
# [19:19:47] DEBUG: Documento 185 dividido en 8 fragmentos.
# [19:19:47] DEBUG: Documento 186 dividido en 9 fragmentos.
# [19:19:47] DEBUG: Documento 187 dividido en 111 fragmentos.
# [19:19:47] DEBUG: Documento 188 dividido en 3 fragmentos.
# [19:19:47] DEBUG: Documento 189 dividido en 58 fragmentos.
# [19:19:47] DEBUG: Documento 190 dividido en 5 fragmentos.
# [19:19:47] DEBUG: Documento 191 dividido en 14 fragmentos.
# [19:19:47] DEBUG: Documento 192 dividido en 5 fragmentos.
# [19:19:47] DEBUG: Documento 193 dividido en 53 fragmentos.
# [19:19:47] DEBUG: Documento 194 dividido en 44 fragmentos.
# [19:19:47] DEBUG: Documento 195 dividido en 21 fragmentos.
# [19:19:47] DEBUG: Documento 196 dividido en 3 fragmentos.
# [19:19:47] DEBUG: Documento 197 dividido en 69 fragmentos.
# [19:19:47] DEBUG: Documento 198 dividido en 25 fragmentos.
# [19:19:47] DEBUG: Documento 199 dividido en 11 fragmentos.
# [19:19:47] DEBUG: Documento 200 dividido en 9 fragmentos.
# [19:19:47] DEBUG: Documento 201 dividido en 8 fragmentos.
# [19:19:47] DEBUG: Documento 202 dividido en 8 fragmentos.
# [19:19:47] DEBUG: Documento 203 dividido en 66 fragmentos.
# [19:19:47] DEBUG: Documento 204 dividido en 10 fragmentos.
# [19:19:47] DEBUG: Documento 205 dividido en 7 fragmentos.
# [19:19:47] DEBUG: Documento 206 dividido en 16 fragmentos.
# [19:19:47] DEBUG: Documento 207 dividido en 5 fragmentos.
# [19:19:47] DEBUG: Documento 208 dividido en 73 fragmentos.
# [19:19:47] DEBUG: Documento 209 dividido en 6 fragmentos.
# [19:19:47] DEBUG: Documento 210 dividido en 66 fragmentos.
# [19:19:47] DEBUG: Documento 211 dividido en 88 fragmentos.
# [19:19:47] DEBUG: Documento 212 dividido en 16 fragmentos.
# [19:19:47] DEBUG: Documento 213 dividido en 48 fragmentos.
# [19:19:47] DEBUG: Documento 214 dividido en 19 fragmentos.
# [19:19:47] DEBUG: Documento 215 dividido en 31 fragmentos.
# [19:19:47] DEBUG: Documento 216 dividido en 3 fragmentos.
# [19:19:47] DEBUG: Documento 217 dividido en 26 fragmentos.
# [19:19:47] DEBUG: Documento 218 dividido en 4 fragmentos.
# [19:19:47] DEBUG: Documento 219 dividido en 71 fragmentos.
# [19:19:47] DEBUG: Documento 220 dividido en 51 fragmentos.
# [19:19:47] DEBUG: Documento 221 dividido en 2 fragmentos.
# [19:19:47] DEBUG: Documento 222 dividido en 1 fragmentos.
# [19:19:47] DEBUG: Documento 223 dividido en 15 fragmentos.
# [19:19:47] DEBUG: Documento 224 dividido en 15 fragmentos.
# [19:19:47] DEBUG: Documento 225 dividido en 2 fragmentos.
# [19:19:47] DEBUG: Documento 226 dividido en 15 fragmentos.
# [19:19:47] DEBUG: Documento 227 dividido en 53 fragmentos.
# [19:19:47] DEBUG: Documento 228 dividido en 6 fragmentos.
# [19:19:47] DEBUG: Documento 229 dividido en 1 fragmentos.
# [19:19:47] DEBUG: Documento 230 dividido en 1 fragmentos.
# [19:19:47] DEBUG: Documento 231 dividido en 17 fragmentos.
# [19:19:47] DEBUG: Documento 232 dividido en 27 fragmentos.
# [19:19:47] DEBUG: Documento 233 dividido en 38 fragmentos.
# [19:19:47] DEBUG: Documento 234 dividido en 13 fragmentos.
# [19:19:47] DEBUG: Documento 235 dividido en 7 fragmentos.
# [19:19:47] DEBUG: Documento 236 dividido en 39 fragmentos.
# [19:19:47] DEBUG: Documento 237 dividido en 36 fragmentos.
# [19:19:47] DEBUG: Documento 238 dividido en 62 fragmentos.
# [19:19:47] DEBUG: Documento 239 dividido en 13 fragmentos.
# [19:19:47] DEBUG: Documento 240 dividido en 76 fragmentos.
# [19:19:47] DEBUG: Documento 241 dividido en 50 fragmentos.
# [19:19:47] DEBUG: Documento 242 dividido en 31 fragmentos.
# [19:19:47] DEBUG: Documento 243 dividido en 16 fragmentos.
# [19:19:47] DEBUG: Documento 244 dividido en 21 fragmentos.
# [19:19:47] DEBUG: Documento 245 dividido en 19 fragmentos.
# [19:19:47] DEBUG: Documento 246 dividido en 19 fragmentos.
# [19:19:47] DEBUG: Documento 247 dividido en 19 fragmentos.
# [19:19:47] DEBUG: Documento 248 dividido en 33 fragmentos.
# [19:19:47] DEBUG: Documento 249 dividido en 8 fragmentos.
# [19:19:47] DEBUG: Documento 250 dividido en 14 fragmentos.
# [19:19:47] DEBUG: Documento 251 dividido en 31 fragmentos.
# [19:19:47] DEBUG: Documento 252 dividido en 24 fragmentos.
# [19:19:47] DEBUG: Documento 253 dividido en 39 fragmentos.
# [19:19:47] DEBUG: Documento 254 dividido en 35 fragmentos.
# [19:19:47] DEBUG: Documento 255 dividido en 47 fragmentos.
# [19:19:47] DEBUG: Documento 256 dividido en 32 fragmentos.
# [19:19:47] DEBUG: Documento 257 dividido en 24 fragmentos.
# [19:19:47] DEBUG: Documento 258 dividido en 54 fragmentos.
# [19:19:47] DEBUG: Documento 259 dividido en 8 fragmentos.
# [19:19:47] DEBUG: Documento 260 dividido en 78 fragmentos.
# [19:19:47] DEBUG: Documento 261 dividido en 31 fragmentos.
# [19:19:47] DEBUG: Documento 262 dividido en 20 fragmentos.
# [19:19:47] DEBUG: Documento 263 dividido en 33 fragmentos.
# [19:19:47] DEBUG: Documento 264 dividido en 69 fragmentos.
# [19:19:47] DEBUG: Documento 265 dividido en 65 fragmentos.
# [19:19:47] DEBUG: Documento 266 dividido en 8 fragmentos.
# [19:19:47] DEBUG: Documento 267 dividido en 21 fragmentos.
# [19:19:47] DEBUG: Documento 268 dividido en 44 fragmentos.
# [19:19:47] DEBUG: Documento 269 dividido en 46 fragmentos.
# [19:19:47] DEBUG: Documento 270 dividido en 28 fragmentos.
# [19:19:47] DEBUG: Documento 271 dividido en 82 fragmentos.
# [19:19:47] DEBUG: Documento 272 dividido en 27 fragmentos.
# [19:19:47] DEBUG: Documento 273 dividido en 20 fragmentos.
# [19:19:47] DEBUG: Documento 274 dividido en 18 fragmentos.
# [19:19:47] DEBUG: Documento 275 dividido en 33 fragmentos.
# [19:19:47] DEBUG: Documento 276 dividido en 82 fragmentos.
# [19:19:47] DEBUG: Documento 277 dividido en 9 fragmentos.
# [19:19:47] DEBUG: Documento 278 dividido en 39 fragmentos.
# [19:19:47] DEBUG: Documento 279 dividido en 44 fragmentos.
# [19:19:47] DEBUG: Documento 280 dividido en 27 fragmentos.
# [19:19:47] DEBUG: Documento 281 dividido en 49 fragmentos.
# [19:19:47] DEBUG: Documento 282 dividido en 49 fragmentos.
# [19:19:47] DEBUG: Documento 283 dividido en 90 fragmentos.
# [19:19:47] DEBUG: Documento 284 dividido en 12 fragmentos.
# [19:19:47] DEBUG: Documento 285 dividido en 41 fragmentos.
# [19:19:47] DEBUG: Documento 286 dividido en 25 fragmentos.
# [19:19:47] DEBUG: Documento 287 dividido en 6 fragmentos.
# [19:19:47] DEBUG: Documento 288 dividido en 21 fragmentos.
# [19:19:47] DEBUG: Documento 289 dividido en 5 fragmentos.
# [19:19:47] DEBUG: Documento 290 dividido en 16 fragmentos.
# [19:19:47] DEBUG: Documento 291 dividido en 3 fragmentos.
# [19:19:47] DEBUG: Documento 292 dividido en 2 fragmentos.
# [19:19:47] DEBUG: Documento 293 dividido en 2 fragmentos.
# [19:19:47] DEBUG: Documento 294 dividido en 6 fragmentos.
# [19:19:47] DEBUG: Documento 295 dividido en 29 fragmentos.
# [19:19:47] DEBUG: Documento 296 dividido en 9 fragmentos.
# [19:19:47] DEBUG: Documento 297 dividido en 13 fragmentos.
# [19:19:47] DEBUG: Documento 298 dividido en 52 fragmentos.
# [19:19:47] DEBUG: Documento 299 dividido en 30 fragmentos.
# [19:19:47] DEBUG: Documento 300 dividido en 6 fragmentos.
# [19:19:47] DEBUG: Documento 301 dividido en 38 fragmentos.
# [19:19:47] DEBUG: Documento 302 dividido en 7 fragmentos.
# [19:19:47] DEBUG: Documento 303 dividido en 10 fragmentos.
# [19:19:47] DEBUG: Documento 304 dividido en 43 fragmentos.
# [19:19:47] DEBUG: Documento 305 dividido en 8 fragmentos.
# [19:19:47] DEBUG: Documento 306 dividido en 2 fragmentos.
# [19:19:47] DEBUG: Documento 307 dividido en 31 fragmentos.
# [19:19:47] DEBUG: Documento 308 dividido en 7 fragmentos.
# [19:19:47] DEBUG: Documento 309 dividido en 50 fragmentos.
# [19:19:47] DEBUG: Documento 310 dividido en 13 fragmentos.
# [19:19:47] DEBUG: Documento 311 dividido en 128 fragmentos.
# [19:19:47] DEBUG: Documento 312 dividido en 34 fragmentos.
# [19:19:47] DEBUG: Documento 313 dividido en 32 fragmentos.
# [19:19:47] DEBUG: Documento 314 dividido en 96 fragmentos.
# [19:19:47] DEBUG: Documento 315 dividido en 295 fragmentos.
# [19:19:47] DEBUG: Documento 316 dividido en 6 fragmentos.
# [19:19:47] DEBUG: Documento 317 dividido en 12 fragmentos.
# [19:19:48] DEBUG: Documento 318 dividido en 33 fragmentos.
# [19:19:48] DEBUG: Documento 319 dividido en 76 fragmentos.
# [19:19:48] DEBUG: Documento 320 dividido en 33 fragmentos.
# [19:19:48] DEBUG: Documento 321 dividido en 46 fragmentos.
# [19:19:48] DEBUG: Documento 322 dividido en 39 fragmentos.
# [19:19:48] DEBUG: Documento 323 dividido en 3 fragmentos.
# [19:19:48] DEBUG: Documento 324 dividido en 17 fragmentos.
# [19:19:48] DEBUG: Documento 325 dividido en 10 fragmentos.
# [19:19:48] DEBUG: Documento 326 dividido en 75 fragmentos.
# [19:19:48] DEBUG: Documento 327 dividido en 2 fragmentos.
# [19:19:48] DEBUG: Documento 328 dividido en 177 fragmentos.
# [19:19:48] DEBUG: Documento 329 dividido en 37 fragmentos.
# [19:19:48] DEBUG: Documento 330 dividido en 26 fragmentos.
# [19:19:48] DEBUG: Documento 331 dividido en 3 fragmentos.
# [19:19:48] DEBUG: Documento 332 dividido en 39 fragmentos.
# [19:19:48] DEBUG: Documento 333 dividido en 39 fragmentos.
# [19:19:48] DEBUG: Documento 334 dividido en 44 fragmentos.
# [19:19:48] DEBUG: Documento 335 dividido en 5 fragmentos.
# [19:19:48] DEBUG: Documento 336 dividido en 9 fragmentos.
# [19:19:48] DEBUG: Documento 337 dividido en 18 fragmentos.
# [19:19:48] DEBUG: Documento 338 dividido en 30 fragmentos.
# [19:19:48] DEBUG: Documento 339 dividido en 1 fragmentos.
# [19:19:48] DEBUG: Documento 340 dividido en 19 fragmentos.
# [19:19:48] DEBUG: Documento 341 dividido en 23 fragmentos.
# [19:19:48] DEBUG: Documento 342 dividido en 28 fragmentos.
# [19:19:48] DEBUG: Documento 343 dividido en 53 fragmentos.
# [19:19:48] DEBUG: Documento 344 dividido en 57 fragmentos.
# [19:19:48] DEBUG: Documento 345 dividido en 50 fragmentos.
# [19:19:48] DEBUG: Documento 346 dividido en 29 fragmentos.
# [19:19:48] DEBUG: Documento 347 dividido en 24 fragmentos.
# [19:19:48] DEBUG: Documento 348 dividido en 8 fragmentos.
# [19:19:48] DEBUG: Documento 349 dividido en 5 fragmentos.
# [19:19:48] DEBUG: Documento 350 dividido en 31 fragmentos.
# [19:19:48] DEBUG: Documento 351 dividido en 20 fragmentos.
# [19:19:48] DEBUG: Documento 352 dividido en 44 fragmentos.
# [19:19:48] DEBUG: Documento 353 dividido en 67 fragmentos.
# [19:19:48] DEBUG: Documento 354 dividido en 20 fragmentos.
# [19:19:48] DEBUG: Documento 355 dividido en 60 fragmentos.
# [19:19:48] DEBUG: Documento 356 dividido en 28 fragmentos.
# [19:19:48] DEBUG: Documento 357 dividido en 25 fragmentos.
# [19:19:48] DEBUG: Documento 358 dividido en 4 fragmentos.
# [19:19:48] DEBUG: Documento 359 dividido en 28 fragmentos.
# [19:19:48] DEBUG: Documento 360 dividido en 14 fragmentos.
# [19:19:48] DEBUG: Documento 361 dividido en 17 fragmentos.
# [19:19:48] DEBUG: Documento 362 dividido en 2 fragmentos.
# [19:19:48] DEBUG: Documento 363 dividido en 130 fragmentos.
# [19:19:48] DEBUG: Documento 364 dividido en 13 fragmentos.
# [19:19:48] DEBUG: Documento 365 dividido en 23 fragmentos.
# [19:19:48] DEBUG: Documento 366 dividido en 38 fragmentos.
# [19:19:48] DEBUG: Documento 367 dividido en 89 fragmentos.
# [19:19:48] DEBUG: Documento 368 dividido en 52 fragmentos.
# [19:19:48] DEBUG: Documento 369 dividido en 4 fragmentos.
# [19:19:48] DEBUG: Documento 370 dividido en 42 fragmentos.
# [19:19:48] DEBUG: Documento 371 dividido en 11 fragmentos.
# [19:19:48] DEBUG: Documento 372 dividido en 23 fragmentos.
# [19:19:48] DEBUG: Documento 373 dividido en 57 fragmentos.
# [19:19:48] DEBUG: Documento 374 dividido en 31 fragmentos.
# [19:19:48] DEBUG: Documento 375 dividido en 23 fragmentos.
# [19:19:48] DEBUG: Documento 376 dividido en 21 fragmentos.
# [19:19:48] DEBUG: Documento 377 dividido en 24 fragmentos.
# [19:19:48] DEBUG: Documento 378 dividido en 9 fragmentos.
# [19:19:48] DEBUG: Documento 379 dividido en 21 fragmentos.
# [19:19:48] DEBUG: Documento 380 dividido en 29 fragmentos.
# [19:19:48] DEBUG: Documento 381 dividido en 9 fragmentos.
# [19:19:48] DEBUG: Documento 382 dividido en 21 fragmentos.
# [19:19:48] DEBUG: Documento 383 dividido en 26 fragmentos.
# [19:19:48] DEBUG: Documento 384 dividido en 20 fragmentos.
# [19:19:48] DEBUG: Documento 385 dividido en 14 fragmentos.
# [19:19:48] DEBUG: Documento 386 dividido en 49 fragmentos.
# [19:19:48] DEBUG: Documento 387 dividido en 23 fragmentos.
# [19:19:48] DEBUG: Documento 388 dividido en 49 fragmentos.
# [19:19:48] DEBUG: Documento 389 dividido en 18 fragmentos.
# [19:19:48] DEBUG: Documento 390 dividido en 20 fragmentos.
# [19:19:48] DEBUG: Documento 391 dividido en 8 fragmentos.
# [19:19:48] DEBUG: Documento 392 dividido en 41 fragmentos.
# [19:19:48] DEBUG: Documento 393 dividido en 27 fragmentos.
# [19:19:48] DEBUG: Documento 394 dividido en 59 fragmentos.
# [19:19:48] DEBUG: Documento 395 dividido en 22 fragmentos.
# [19:19:48] DEBUG: Documento 396 dividido en 51 fragmentos.
# [19:19:48] DEBUG: Documento 397 dividido en 20 fragmentos.
# [19:19:48] DEBUG: Documento 398 dividido en 10 fragmentos.
# [19:19:48] DEBUG: Documento 399 dividido en 59 fragmentos.
# [19:19:48] DEBUG: Documento 400 dividido en 2 fragmentos.
# [19:19:48] DEBUG: Documento 401 dividido en 5 fragmentos.
# [19:19:48] DEBUG: Documento 402 dividido en 28 fragmentos.
# [19:19:48] DEBUG: Documento 403 dividido en 10 fragmentos.
# [19:19:48] DEBUG: Documento 404 dividido en 34 fragmentos.
# [19:19:48] DEBUG: Documento 405 dividido en 17 fragmentos.
# [19:19:48] DEBUG: Documento 406 dividido en 1 fragmentos.
# [19:19:48] DEBUG: Documento 407 dividido en 13 fragmentos.
# [19:19:48] DEBUG: Documento 408 dividido en 13 fragmentos.
# [19:19:48] DEBUG: Documento 409 dividido en 30 fragmentos.
# [19:19:48] DEBUG: Documento 410 dividido en 35 fragmentos.
# [19:19:48] DEBUG: Documento 411 dividido en 16 fragmentos.
# [19:19:48] DEBUG: Documento 412 dividido en 14 fragmentos.
# [19:19:48] DEBUG: Documento 413 dividido en 18 fragmentos.
# [19:19:48] DEBUG: Documento 414 dividido en 16 fragmentos.
# [19:19:48] DEBUG: Documento 415 dividido en 19 fragmentos.
# [19:19:48] DEBUG: Documento 416 dividido en 22 fragmentos.
# [19:19:48] DEBUG: Documento 417 dividido en 27 fragmentos.
# [19:19:48] DEBUG: Documento 418 dividido en 41 fragmentos.
# [19:19:48] DEBUG: Documento 419 dividido en 32 fragmentos.
# [19:19:48] DEBUG: Documento 420 dividido en 58 fragmentos.
# [19:19:48] DEBUG: Documento 421 dividido en 5 fragmentos.
# [19:19:48] DEBUG: Documento 422 dividido en 54 fragmentos.
# [19:19:48] DEBUG: Documento 423 dividido en 29 fragmentos.
# [19:19:48] DEBUG: Documento 424 dividido en 8 fragmentos.
# [19:19:48] DEBUG: Documento 425 dividido en 1 fragmentos.
# [19:19:48] DEBUG: Documento 426 dividido en 58 fragmentos.
# [19:19:48] DEBUG: Documento 427 dividido en 2 fragmentos.
# [19:19:48] DEBUG: Documento 428 dividido en 1 fragmentos.
# [19:19:48] DEBUG: Documento 429 dividido en 5 fragmentos.
# [19:19:48] DEBUG: Documento 430 dividido en 20 fragmentos.
# [19:19:48] DEBUG: Documento 431 dividido en 21 fragmentos.
# [19:19:48] DEBUG: Documento 432 dividido en 43 fragmentos.
# [19:19:48] DEBUG: Documento 433 dividido en 9 fragmentos.
# [19:19:48] DEBUG: Documento 434 dividido en 7 fragmentos.
# [19:19:48] DEBUG: Documento 435 dividido en 32 fragmentos.
# [19:19:48] DEBUG: Documento 436 dividido en 49 fragmentos.
# [19:19:48] DEBUG: Documento 437 dividido en 9 fragmentos.
# [19:19:48] DEBUG: Documento 438 dividido en 7 fragmentos.
# [19:19:48] DEBUG: Documento 439 dividido en 39 fragmentos.
# [19:19:48] DEBUG: Documento 440 dividido en 5 fragmentos.
# [19:19:48] DEBUG: Documento 441 dividido en 7 fragmentos.
# [19:19:48] DEBUG: Documento 442 dividido en 4 fragmentos.
# [19:19:48] DEBUG: Documento 443 dividido en 24 fragmentos.
# [19:19:48] DEBUG: Documento 444 dividido en 5 fragmentos.
# [19:19:48] DEBUG: Documento 445 dividido en 18 fragmentos.
# [19:19:48] DEBUG: Documento 446 dividido en 6 fragmentos.
# [19:19:48] DEBUG: Documento 447 dividido en 36 fragmentos.
# [19:19:48] DEBUG: Documento 448 dividido en 33 fragmentos.
# [19:19:48] DEBUG: Documento 449 dividido en 1 fragmentos.
# [19:19:48] DEBUG: Documento 450 dividido en 34 fragmentos.
# [19:19:48] DEBUG: Documento 451 dividido en 25 fragmentos.
# [19:19:48] DEBUG: Documento 452 dividido en 6 fragmentos.
# [19:19:48] DEBUG: Documento 453 dividido en 61 fragmentos.
# [19:19:48] DEBUG: Documento 454 dividido en 21 fragmentos.
# [19:19:48] DEBUG: Documento 455 dividido en 33 fragmentos.
# [19:19:48] DEBUG: Documento 456 dividido en 46 fragmentos.
# [19:19:48] DEBUG: Documento 457 dividido en 45 fragmentos.
# [19:19:48] DEBUG: Documento 458 dividido en 42 fragmentos.
# [19:19:48] DEBUG: Documento 459 dividido en 30 fragmentos.
# [19:19:48] DEBUG: Documento 460 dividido en 32 fragmentos.
# [19:19:48] DEBUG: Documento 461 dividido en 2 fragmentos.
# [19:19:48] DEBUG: Documento 462 dividido en 34 fragmentos.
# [19:19:48] DEBUG: Documento 463 dividido en 26 fragmentos.
# [19:19:48] DEBUG: Documento 464 dividido en 4 fragmentos.
# [19:19:48] DEBUG: Documento 465 dividido en 24 fragmentos.
# [19:19:48] DEBUG: Documento 466 dividido en 39 fragmentos.
# [19:19:48] DEBUG: Documento 467 dividido en 64 fragmentos.
# [19:19:48] DEBUG: Documento 468 dividido en 67 fragmentos.
# [19:19:48] DEBUG: Documento 469 dividido en 6 fragmentos.
# [19:19:48] DEBUG: Documento 470 dividido en 22 fragmentos.
# [19:19:48] DEBUG: Documento 471 dividido en 29 fragmentos.
# [19:19:48] DEBUG: Documento 472 dividido en 23 fragmentos.
# [19:19:48] DEBUG: Documento 473 dividido en 23 fragmentos.
# [19:19:48] DEBUG: Documento 474 dividido en 43 fragmentos.
# [19:19:48] DEBUG: Documento 475 dividido en 36 fragmentos.
# [19:19:48] DEBUG: Documento 476 dividido en 64 fragmentos.
# [19:19:48] DEBUG: Documento 477 dividido en 33 fragmentos.
# [19:19:49] DEBUG: Documento 478 dividido en 54 fragmentos.
# [19:19:49] DEBUG: Documento 479 dividido en 26 fragmentos.
# [19:19:49] DEBUG: Documento 480 dividido en 29 fragmentos.
# [19:19:49] DEBUG: Documento 481 dividido en 16 fragmentos.
# [19:19:49] DEBUG: Documento 482 dividido en 24 fragmentos.
# [19:19:49] DEBUG: Documento 483 dividido en 9 fragmentos.
# [19:19:49] DEBUG: Documento 484 dividido en 12 fragmentos.
# [19:19:49] DEBUG: Documento 485 dividido en 15 fragmentos.
# [19:19:49] DEBUG: Documento 486 dividido en 70 fragmentos.
# [19:19:49] DEBUG: Documento 487 dividido en 15 fragmentos.
# [19:19:49] DEBUG: Documento 488 dividido en 15 fragmentos.
# [19:19:49] DEBUG: Documento 489 dividido en 28 fragmentos.
# [19:19:49] DEBUG: Documento 490 dividido en 6 fragmentos.
# [19:19:49] DEBUG: Documento 491 dividido en 8 fragmentos.
# [19:19:49] DEBUG: Documento 492 dividido en 80 fragmentos.
# [19:19:49] DEBUG: Documento 493 dividido en 123 fragmentos.
# [19:19:49] DEBUG: Documento 494 dividido en 851 fragmentos.
# [19:19:49] DEBUG: Documento 495 dividido en 1 fragmentos.
# [19:19:49] DEBUG: Documento 496 dividido en 26 fragmentos.
# [19:19:49] DEBUG: Documento 497 dividido en 3 fragmentos.
# [19:19:49] DEBUG: Documento 498 dividido en 1 fragmentos.
# [19:19:49] DEBUG: Documento 499 dividido en 29 fragmentos.
# [19:19:49] DEBUG: Documento 500 dividido en 28 fragmentos.
# [19:19:49] DEBUG: Documento 501 dividido en 16 fragmentos.
# [19:19:49] DEBUG: Documento 502 dividido en 33 fragmentos.
# [19:19:49] DEBUG: Documento 503 dividido en 18 fragmentos.
# [19:19:49] DEBUG: Documento 504 dividido en 10 fragmentos.
# [19:19:49] DEBUG: Documento 505 dividido en 40 fragmentos.
# [19:19:49] DEBUG: Documento 506 dividido en 9 fragmentos.
# [19:19:49] DEBUG: Documento 507 dividido en 30 fragmentos.
# [19:19:49] DEBUG: Documento 508 dividido en 9 fragmentos.
# [19:19:49] DEBUG: Documento 509 dividido en 2 fragmentos.
# [19:19:49] DEBUG: Documento 510 dividido en 4 fragmentos.
# [19:19:49] DEBUG: Documento 511 dividido en 38 fragmentos.
# [19:19:49] DEBUG: Documento 512 dividido en 29 fragmentos.
# [19:19:49] DEBUG: Documento 513 dividido en 26 fragmentos.
# [19:19:49] DEBUG: Documento 514 dividido en 1 fragmentos.
# [19:19:49] DEBUG: Documento 515 dividido en 61 fragmentos.
# [19:19:49] DEBUG: Documento 516 dividido en 24 fragmentos.
# [19:19:49] DEBUG: Documento 517 dividido en 12 fragmentos.
# [19:19:49] DEBUG: Documento 518 dividido en 41 fragmentos.
# [19:19:49] DEBUG: Documento 519 dividido en 26 fragmentos.
# [19:19:49] DEBUG: Documento 520 dividido en 4 fragmentos.
# [19:19:49] DEBUG: Documento 521 dividido en 10 fragmentos.
# [19:19:49] DEBUG: Documento 522 dividido en 20 fragmentos.
# [19:19:49] DEBUG: Documento 523 dividido en 2 fragmentos.
# [19:19:49] DEBUG: Documento 524 dividido en 80 fragmentos.
# [19:19:49] DEBUG: Documento 525 dividido en 62 fragmentos.
# [19:19:49] DEBUG: Documento 526 dividido en 61 fragmentos.
# [19:19:49] DEBUG: Documento 527 dividido en 53 fragmentos.
# [19:19:49] DEBUG: Documento 528 dividido en 94 fragmentos.
# [19:19:49] DEBUG: Documento 529 dividido en 59 fragmentos.
# [19:19:49] DEBUG: Documento 530 dividido en 91 fragmentos.
# [19:19:49] DEBUG: Documento 531 dividido en 60 fragmentos.
# [19:19:49] DEBUG: Documento 532 dividido en 30 fragmentos.
# [19:19:49] DEBUG: Documento 533 dividido en 26 fragmentos.
# [19:19:49] DEBUG: Documento 534 dividido en 20 fragmentos.
# [19:19:49] DEBUG: Documento 535 dividido en 53 fragmentos.
# [19:19:49] DEBUG: Documento 536 dividido en 24 fragmentos.
# [19:19:49] DEBUG: Documento 537 dividido en 43 fragmentos.
# [19:19:49] DEBUG: Documento 538 dividido en 33 fragmentos.
# [19:19:49] DEBUG: Documento 539 dividido en 55 fragmentos.
# [19:19:49] DEBUG: Documento 540 dividido en 70 fragmentos.
# [19:19:49] DEBUG: Documento 541 dividido en 57 fragmentos.
# [19:19:49] DEBUG: Documento 542 dividido en 90 fragmentos.
# [19:19:49] DEBUG: Documento 543 dividido en 30 fragmentos.
# [19:19:49] DEBUG: Documento 544 dividido en 103 fragmentos.
# [19:19:49] DEBUG: Documento 545 dividido en 12 fragmentos.
# [19:19:49] DEBUG: Documento 546 dividido en 55 fragmentos.
# [19:19:49] DEBUG: Documento 547 dividido en 41 fragmentos.
# [19:19:49] DEBUG: Documento 548 dividido en 41 fragmentos.
# [19:19:49] DEBUG: Documento 549 dividido en 55 fragmentos.
# [19:19:49] DEBUG: Documento 550 dividido en 71 fragmentos.
# [19:19:49] DEBUG: Documento 551 dividido en 28 fragmentos.
# [19:19:49] DEBUG: Documento 552 dividido en 63 fragmentos.
# [19:19:49] DEBUG: Documento 553 dividido en 2 fragmentos.
# [19:19:49] DEBUG: Documento 554 dividido en 21 fragmentos.
# [19:19:49] DEBUG: Documento 555 dividido en 31 fragmentos.
# [19:19:49] DEBUG: Documento 556 dividido en 29 fragmentos.
# [19:19:49] DEBUG: Documento 557 dividido en 42 fragmentos.
# [19:19:49] DEBUG: Documento 558 dividido en 40 fragmentos.
# [19:19:49] DEBUG: Documento 559 dividido en 29 fragmentos.
# [19:19:49] DEBUG: Documento 560 dividido en 1 fragmentos.
# [19:19:49] DEBUG: Documento 561 dividido en 10 fragmentos.
# [19:19:49] DEBUG: Documento 562 dividido en 21 fragmentos.
# [19:19:49] DEBUG: Documento 563 dividido en 109 fragmentos.
# [19:19:49] DEBUG: Documento 564 dividido en 3 fragmentos.
# [19:19:49] DEBUG: Documento 565 dividido en 10 fragmentos.
# [19:19:49] DEBUG: Documento 566 dividido en 11 fragmentos.
# [19:19:49] DEBUG: Documento 567 dividido en 16 fragmentos.
# [19:19:49] DEBUG: Documento 568 dividido en 61 fragmentos.
# [19:19:49] DEBUG: Documento 569 dividido en 25 fragmentos.
# [19:19:49] DEBUG: Documento 570 dividido en 15 fragmentos.
# [19:19:49] DEBUG: Documento 571 dividido en 117 fragmentos.
# [19:19:49] DEBUG: Documento 572 dividido en 16 fragmentos.
# [19:19:49] DEBUG: Documento 573 dividido en 2 fragmentos.
# [19:19:49] DEBUG: Documento 574 dividido en 15 fragmentos.
# [19:19:49] DEBUG: Documento 575 dividido en 28 fragmentos.
# [19:19:49] DEBUG: Documento 576 dividido en 9 fragmentos.
# [19:19:49] DEBUG: Documento 577 dividido en 23 fragmentos.
# [19:19:49] DEBUG: Documento 578 dividido en 34 fragmentos.
# [19:19:49] DEBUG: Documento 579 dividido en 17 fragmentos.
# [19:19:49] DEBUG: Documento 580 dividido en 4 fragmentos.
# [19:19:49] DEBUG: Documento 581 dividido en 9 fragmentos.
# [19:19:49] DEBUG: Documento 582 dividido en 25 fragmentos.
# [19:19:49] DEBUG: Documento 583 dividido en 72 fragmentos.
# [19:19:49] DEBUG: Documento 584 dividido en 12 fragmentos.
# [19:19:49] DEBUG: Documento 585 dividido en 4 fragmentos.
# [19:19:49] DEBUG: Documento 586 dividido en 9 fragmentos.
# [19:19:49] DEBUG: Documento 587 dividido en 59 fragmentos.
# [19:19:49] DEBUG: Documento 588 dividido en 26 fragmentos.
# [19:19:49] DEBUG: Documento 589 dividido en 22 fragmentos.
# [19:19:49] DEBUG: Documento 590 dividido en 29 fragmentos.
# [19:19:49] DEBUG: Documento 591 dividido en 14 fragmentos.
# [19:19:49] DEBUG: Documento 592 dividido en 5 fragmentos.
# [19:19:49] DEBUG: Documento 593 dividido en 18 fragmentos.
# [19:19:49] DEBUG: Documento 594 dividido en 13 fragmentos.
# [19:19:49] DEBUG: Documento 595 dividido en 31 fragmentos.
# [19:19:49] DEBUG: Documento 596 dividido en 21 fragmentos.
# [19:19:49] DEBUG: Documento 597 dividido en 3 fragmentos.
# [19:19:49] DEBUG: Documento 598 dividido en 54 fragmentos.
# [19:19:49] DEBUG: Documento 599 dividido en 3 fragmentos.
# [19:19:49] DEBUG: Documento 600 dividido en 7 fragmentos.
# [19:19:49] DEBUG: Documento 601 dividido en 47 fragmentos.
# [19:19:49] DEBUG: Documento 602 dividido en 104 fragmentos.
# [19:19:49] DEBUG: Documento 603 dividido en 30 fragmentos.
# [19:19:49] DEBUG: Documento 604 dividido en 44 fragmentos.
# [19:19:49] DEBUG: Documento 605 dividido en 41 fragmentos.
# [19:19:49] DEBUG: Documento 606 dividido en 77 fragmentos.
# [19:19:49] DEBUG: Documento 607 dividido en 50 fragmentos.
# [19:19:50] DEBUG: Documento 608 dividido en 26 fragmentos.
# [19:19:50] DEBUG: Documento 609 dividido en 10 fragmentos.
# [19:19:50] DEBUG: Documento 610 dividido en 6 fragmentos.
# [19:19:50] DEBUG: Documento 611 dividido en 7 fragmentos.
# [19:19:50] DEBUG: Documento 612 dividido en 38 fragmentos.
# [19:19:50] DEBUG: Documento 613 dividido en 41 fragmentos.
# [19:19:50] DEBUG: Documento 614 dividido en 12 fragmentos.
# [19:19:50] DEBUG: Documento 615 dividido en 8 fragmentos.
# [19:19:50] DEBUG: Documento 616 dividido en 8 fragmentos.
# [19:19:50] DEBUG: Documento 617 dividido en 34 fragmentos.
# [19:19:50] DEBUG: Documento 618 dividido en 61 fragmentos.
# [19:19:50] DEBUG: Documento 619 dividido en 44 fragmentos.
# [19:19:50] DEBUG: Documento 620 dividido en 34 fragmentos.
# [19:19:50] DEBUG: Documento 621 dividido en 12 fragmentos.
# [19:19:50] DEBUG: Documento 622 dividido en 5 fragmentos.
# [19:19:50] DEBUG: Documento 623 dividido en 48 fragmentos.
# [19:19:50] DEBUG: Documento 624 dividido en 6 fragmentos.
# [19:19:50] DEBUG: Documento 625 dividido en 30 fragmentos.
# [19:19:50] DEBUG: Documento 626 dividido en 26 fragmentos.
# [19:19:50] DEBUG: Documento 627 dividido en 20 fragmentos.
# [19:19:50] DEBUG: Documento 628 dividido en 4 fragmentos.
# [19:19:50] DEBUG: Documento 629 dividido en 21 fragmentos.
# [19:19:50] DEBUG: Documento 630 dividido en 5 fragmentos.
# [19:19:50] DEBUG: Documento 631 dividido en 23 fragmentos.
# [19:19:50] DEBUG: Documento 632 dividido en 30 fragmentos.
# [19:19:50] DEBUG: Documento 633 dividido en 4 fragmentos.
# [19:19:50] DEBUG: Documento 634 dividido en 23 fragmentos.
# [19:19:50] DEBUG: Documento 635 dividido en 26 fragmentos.
# [19:19:50] DEBUG: Documento 636 dividido en 19 fragmentos.
# [19:19:50] DEBUG: Documento 637 dividido en 34 fragmentos.
# [19:19:50] DEBUG: Documento 638 dividido en 41 fragmentos.
# [19:19:50] DEBUG: Documento 639 dividido en 44 fragmentos.
# [19:19:50] DEBUG: Documento 640 dividido en 27 fragmentos.
# [19:19:50] DEBUG: Documento 641 dividido en 20 fragmentos.
# [19:19:50] DEBUG: Documento 642 dividido en 6 fragmentos.
# [19:19:50] DEBUG: Documento 643 dividido en 87 fragmentos.
# [19:19:50] DEBUG: Documento 644 dividido en 18 fragmentos.
# [19:19:50] DEBUG: Documento 645 dividido en 47 fragmentos.
# [19:19:50] DEBUG: Documento 646 dividido en 26 fragmentos.
# [19:19:50] DEBUG: Documento 647 dividido en 22 fragmentos.
# [19:19:50] DEBUG: Documento 648 dividido en 32 fragmentos.
# [19:19:50] DEBUG: Documento 649 dividido en 14 fragmentos.
# [19:19:50] DEBUG: Documento 650 dividido en 24 fragmentos.
# [19:19:50] DEBUG: Documento 651 dividido en 23 fragmentos.
# [19:19:50] DEBUG: Documento 652 dividido en 23 fragmentos.
# [19:19:50] DEBUG: Documento 653 dividido en 45 fragmentos.
# [19:19:50] DEBUG: Documento 654 dividido en 24 fragmentos.
# [19:19:50] DEBUG: Documento 655 dividido en 4 fragmentos.
# [19:19:50] DEBUG: Documento 656 dividido en 56 fragmentos.
# [19:19:50] DEBUG: Documento 657 dividido en 41 fragmentos.
# [19:19:50] DEBUG: Documento 658 dividido en 47 fragmentos.
# [19:19:50] DEBUG: Documento 659 dividido en 21 fragmentos.
# [19:19:50] DEBUG: Documento 660 dividido en 34 fragmentos.
# [19:19:50] DEBUG: Documento 661 dividido en 17 fragmentos.
# [19:19:50] DEBUG: Documento 662 dividido en 22 fragmentos.
# [19:19:50] DEBUG: Documento 663 dividido en 8 fragmentos.
# [19:19:50] DEBUG: Documento 664 dividido en 7 fragmentos.
# [19:19:50] DEBUG: Documento 665 dividido en 69 fragmentos.
# [19:19:50] DEBUG: Documento 666 dividido en 24 fragmentos.
# [19:19:50] DEBUG: Documento 667 dividido en 2 fragmentos.
# [19:19:50] DEBUG: Documento 668 dividido en 28 fragmentos.
# [19:19:50] DEBUG: Documento 669 dividido en 4 fragmentos.
# [19:19:50] DEBUG: Documento 670 dividido en 24 fragmentos.
# [19:19:50] DEBUG: Documento 671 dividido en 23 fragmentos.
# [19:19:50] DEBUG: Documento 672 dividido en 13 fragmentos.
# [19:19:50] DEBUG: Documento 673 dividido en 6 fragmentos.
# [19:19:50] DEBUG: Documento 674 dividido en 52 fragmentos.
# [19:19:50] DEBUG: Documento 675 dividido en 28 fragmentos.
# [19:19:50] DEBUG: Documento 676 dividido en 52 fragmentos.
# [19:19:50] DEBUG: Documento 677 dividido en 33 fragmentos.
# [19:19:50] DEBUG: Documento 678 dividido en 6 fragmentos.
# [19:19:50] DEBUG: Documento 679 dividido en 35 fragmentos.
# [19:19:50] DEBUG: Documento 680 dividido en 3 fragmentos.
# [19:19:50] DEBUG: Documento 681 dividido en 13 fragmentos.
# [19:19:50] DEBUG: Documento 682 dividido en 37 fragmentos.
# [19:19:50] DEBUG: Documento 683 dividido en 21 fragmentos.
# [19:19:50] DEBUG: Documento 684 dividido en 1 fragmentos.
# [19:19:50] DEBUG: Documento 685 dividido en 59 fragmentos.
# [19:19:50] DEBUG: Documento 686 dividido en 83 fragmentos.
# [19:19:50] DEBUG: Documento 687 dividido en 14 fragmentos.
# [19:19:50] DEBUG: Documento 688 dividido en 34 fragmentos.
# [19:19:50] DEBUG: Documento 689 dividido en 25 fragmentos.
# [19:19:50] DEBUG: Documento 690 dividido en 23 fragmentos.
# [19:19:50] DEBUG: Documento 691 dividido en 35 fragmentos.
# [19:19:50] DEBUG: Documento 692 dividido en 41 fragmentos.
# [19:19:50] DEBUG: Documento 693 dividido en 2 fragmentos.
# [19:19:50] DEBUG: Documento 694 dividido en 51 fragmentos.
# [19:19:50] DEBUG: Documento 695 dividido en 33 fragmentos.
# [19:19:50] DEBUG: Documento 696 dividido en 24 fragmentos.
# [19:19:50] DEBUG: Documento 697 dividido en 25 fragmentos.
# [19:19:50] DEBUG: Documento 698 dividido en 24 fragmentos.
# [19:19:50] DEBUG: Documento 699 dividido en 41 fragmentos.
# [19:19:50] DEBUG: Documento 700 dividido en 21 fragmentos.
# [19:19:50] DEBUG: Documento 701 dividido en 49 fragmentos.
# [19:19:50] DEBUG: Documento 702 dividido en 47 fragmentos.
# [19:19:50] DEBUG: Documento 703 dividido en 61 fragmentos.
# [19:19:50] DEBUG: Documento 704 dividido en 6 fragmentos.
# [19:19:50] DEBUG: Documento 705 dividido en 31 fragmentos.
# [19:19:50] DEBUG: Documento 706 dividido en 28 fragmentos.
# [19:19:50] DEBUG: Documento 707 dividido en 17 fragmentos.
# [19:19:50] DEBUG: Documento 708 dividido en 46 fragmentos.
# [19:19:50] DEBUG: Documento 709 dividido en 59 fragmentos.
# [19:19:50] DEBUG: Documento 710 dividido en 10 fragmentos.
# [19:19:50] DEBUG: Documento 711 dividido en 36 fragmentos.
# [19:19:50] DEBUG: Documento 712 dividido en 251 fragmentos.
# [19:19:50] DEBUG: Documento 713 dividido en 21 fragmentos.
# [19:19:50] DEBUG: Documento 714 dividido en 69 fragmentos.
# [19:19:50] DEBUG: Documento 715 dividido en 31 fragmentos.
# [19:19:50] DEBUG: Documento 716 dividido en 32 fragmentos.
# [19:19:50] DEBUG: Documento 717 dividido en 15 fragmentos.
# [19:19:50] DEBUG: Documento 718 dividido en 59 fragmentos.
# [19:19:50] DEBUG: Documento 719 dividido en 27 fragmentos.
# [19:19:50] DEBUG: Documento 720 dividido en 35 fragmentos.
# [19:19:50] DEBUG: Documento 721 dividido en 79 fragmentos.
# [19:19:50] DEBUG: Documento 722 dividido en 16 fragmentos.
# [19:19:50] DEBUG: Documento 723 dividido en 56 fragmentos.
# [19:19:50] DEBUG: Documento 724 dividido en 32 fragmentos.
# [19:19:50] DEBUG: Documento 725 dividido en 73 fragmentos.
# [19:19:50] DEBUG: Documento 726 dividido en 22 fragmentos.
# [19:19:50] DEBUG: Documento 727 dividido en 42 fragmentos.
# [19:19:50] DEBUG: Documento 728 dividido en 31 fragmentos.
# [19:19:50] DEBUG: Documento 729 dividido en 15 fragmentos.
# [19:19:50] DEBUG: Documento 730 dividido en 2 fragmentos.
# [19:19:50] DEBUG: Documento 731 dividido en 53 fragmentos.
# [19:19:50] DEBUG: Documento 732 dividido en 47 fragmentos.
# [19:19:50] DEBUG: Documento 733 dividido en 34 fragmentos.
# [19:19:51] DEBUG: Documento 734 dividido en 114 fragmentos.
# [19:19:51] DEBUG: Documento 735 dividido en 5 fragmentos.
# [19:19:51] DEBUG: Documento 736 dividido en 7 fragmentos.
# [19:19:51] DEBUG: Documento 737 dividido en 37 fragmentos.
# [19:19:51] DEBUG: Documento 738 dividido en 49 fragmentos.
# [19:19:51] DEBUG: Documento 739 dividido en 38 fragmentos.
# [19:19:51] DEBUG: Documento 740 dividido en 45 fragmentos.
# [19:19:51] DEBUG: Documento 741 dividido en 10 fragmentos.
# [19:19:51] DEBUG: Documento 742 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 743 dividido en 58 fragmentos.
# [19:19:51] DEBUG: Documento 744 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 745 dividido en 108 fragmentos.
# [19:19:51] DEBUG: Documento 746 dividido en 6 fragmentos.
# [19:19:51] DEBUG: Documento 747 dividido en 34 fragmentos.
# [19:19:51] DEBUG: Documento 748 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 749 dividido en 38 fragmentos.
# [19:19:51] DEBUG: Documento 750 dividido en 12 fragmentos.
# [19:19:51] DEBUG: Documento 751 dividido en 262 fragmentos.
# [19:19:51] DEBUG: Documento 752 dividido en 20 fragmentos.
# [19:19:51] DEBUG: Documento 753 dividido en 37 fragmentos.
# [19:19:51] DEBUG: Documento 754 dividido en 14 fragmentos.
# [19:19:51] DEBUG: Documento 755 dividido en 17 fragmentos.
# [19:19:51] DEBUG: Documento 756 dividido en 17 fragmentos.
# [19:19:51] DEBUG: Documento 757 dividido en 11 fragmentos.
# [19:19:51] DEBUG: Documento 758 dividido en 3 fragmentos.
# [19:19:51] DEBUG: Documento 759 dividido en 46 fragmentos.
# [19:19:51] DEBUG: Documento 760 dividido en 46 fragmentos.
# [19:19:51] DEBUG: Documento 761 dividido en 37 fragmentos.
# [19:19:51] DEBUG: Documento 762 dividido en 26 fragmentos.
# [19:19:51] DEBUG: Documento 763 dividido en 38 fragmentos.
# [19:19:51] DEBUG: Documento 764 dividido en 54 fragmentos.
# [19:19:51] DEBUG: Documento 765 dividido en 11 fragmentos.
# [19:19:51] DEBUG: Documento 766 dividido en 27 fragmentos.
# [19:19:51] DEBUG: Documento 767 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 768 dividido en 11 fragmentos.
# [19:19:51] DEBUG: Documento 769 dividido en 53 fragmentos.
# [19:19:51] DEBUG: Documento 770 dividido en 30 fragmentos.
# [19:19:51] DEBUG: Documento 771 dividido en 4 fragmentos.
# [19:19:51] DEBUG: Documento 772 dividido en 164 fragmentos.
# [19:19:51] DEBUG: Documento 773 dividido en 164 fragmentos.
# [19:19:51] DEBUG: Documento 774 dividido en 164 fragmentos.
# [19:19:51] DEBUG: Documento 775 dividido en 3 fragmentos.
# [19:19:51] DEBUG: Documento 776 dividido en 18 fragmentos.
# [19:19:51] DEBUG: Documento 777 dividido en 44 fragmentos.
# [19:19:51] DEBUG: Documento 778 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 779 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 780 dividido en 124 fragmentos.
# [19:19:51] DEBUG: Documento 781 dividido en 44 fragmentos.
# [19:19:51] DEBUG: Documento 782 dividido en 4 fragmentos.
# [19:19:51] DEBUG: Documento 783 dividido en 103 fragmentos.
# [19:19:51] DEBUG: Documento 784 dividido en 8 fragmentos.
# [19:19:51] DEBUG: Documento 785 dividido en 21 fragmentos.
# [19:19:51] DEBUG: Documento 786 dividido en 106 fragmentos.
# [19:19:51] DEBUG: Documento 787 dividido en 51 fragmentos.
# [19:19:51] DEBUG: Documento 788 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 789 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 790 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 791 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 792 dividido en 3 fragmentos.
# [19:19:51] DEBUG: Documento 793 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 794 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 795 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 796 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 797 dividido en 3 fragmentos.
# [19:19:51] DEBUG: Documento 798 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 799 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 800 dividido en 6 fragmentos.
# [19:19:51] DEBUG: Documento 801 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 802 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 803 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 804 dividido en 4 fragmentos.
# [19:19:51] DEBUG: Documento 805 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 806 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 807 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 808 dividido en 3 fragmentos.
# [19:19:51] DEBUG: Documento 809 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 810 dividido en 2 fragmentos.
# [19:19:51] DEBUG: Documento 811 dividido en 6 fragmentos.
# [19:19:51] DEBUG: Documento 812 dividido en 8 fragmentos.
# [19:19:51] DEBUG: Documento 813 dividido en 21 fragmentos.
# [19:19:51] DEBUG: Documento 814 dividido en 1 fragmentos.
# [19:19:51] DEBUG: Documento 815 dividido en 2 fragmentos.
# ...
# [19:20:03] DEBUG: Documento 2582 dividido en 23 fragmentos.
# [19:20:03] DEBUG: Documento 2583 dividido en 15 fragmentos.
# [19:20:03] DEBUG: Documento 2584 dividido en 5 fragmentos.
# [19:20:03] DEBUG: Documento 2585 dividido en 54 fragmentos.
# [19:20:03] DEBUG: Documento 2586 dividido en 29 fragmentos.
# [19:20:03] DEBUG: Documento 2587 dividido en 16 fragmentos.
# [19:20:03] DEBUG: Documento 2588 dividido en 48 fragmentos.
# [19:20:03] DEBUG: Documento 2589 dividido en 23 fragmentos.
# [19:20:03] DEBUG: Documento 2590 dividido en 30 fragmentos.
# [19:20:03] DEBUG: Documento 2591 dividido en 41 fragmentos.
# [19:20:03] DEBUG: Documento 2592 dividido en 46 fragmentos.
# [19:20:03] DEBUG: Documento 2593 dividido en 105 fragmentos.
# [19:20:03] DEBUG: Documento 2594 dividido en 49 fragmentos.
# [19:20:03] DEBUG: Documento 2595 dividido en 42 fragmentos.
# [19:20:03] DEBUG: Documento 2596 dividido en 33 fragmentos.
# [19:20:03] DEBUG: Documento 2597 dividido en 30 fragmentos.
# [19:20:03] DEBUG: Documento 2598 dividido en 17 fragmentos.
# [19:20:03] DEBUG: Documento 2599 dividido en 47 fragmentos.
# [19:20:03] DEBUG: Documento 2600 dividido en 7 fragmentos.
# [19:20:03] DEBUG: Documento 2601 dividido en 8 fragmentos.
# [19:20:03] DEBUG: Documento 2602 dividido en 13 fragmentos.
# [19:20:03] DEBUG: Documento 2603 dividido en 9 fragmentos.
# [19:20:03] DEBUG: Documento 2604 dividido en 10 fragmentos.
# [19:20:03] DEBUG: Documento 2605 dividido en 3 fragmentos.
# [19:20:03] DEBUG: Documento 2606 dividido en 13 fragmentos.
# [19:20:03] DEBUG: Documento 2607 dividido en 37 fragmentos.
# [19:20:03] DEBUG: Documento 2608 dividido en 31 fragmentos.
# [19:20:03] DEBUG: Documento 2609 dividido en 42 fragmentos.
# [19:20:03] DEBUG: Documento 2610 dividido en 33 fragmentos.
# [19:20:03] DEBUG: Documento 2611 dividido en 32 fragmentos.
# [19:20:03] DEBUG: Documento 2612 dividido en 58 fragmentos.
# [19:20:03] DEBUG: Documento 2613 dividido en 43 fragmentos.
# [19:20:03] DEBUG: Documento 2614 dividido en 8 fragmentos.
# [19:20:03] DEBUG: Documento 2615 dividido en 8 fragmentos.
# [19:20:03] DEBUG: Documento 2616 dividido en 60 fragmentos.
# [19:20:03] DEBUG: Documento 2617 dividido en 12 fragmentos.
# [19:20:03] DEBUG: Documento 2618 dividido en 18 fragmentos.
# [19:20:03] DEBUG: Documento 2619 dividido en 43 fragmentos.
# [19:20:03] DEBUG: Documento 2620 dividido en 21 fragmentos.
# [19:20:03] DEBUG: Documento 2621 dividido en 86 fragmentos.
# [19:20:03] DEBUG: Documento 2622 dividido en 52 fragmentos.
# [19:20:03] DEBUG: Documento 2623 dividido en 43 fragmentos.
# [19:20:03] DEBUG: Documento 2624 dividido en 57 fragmentos.
# [19:20:03] DEBUG: Documento 2625 dividido en 61 fragmentos.
# [19:20:03] DEBUG: Documento 2626 dividido en 49 fragmentos.
# [19:20:03] DEBUG: Documento 2627 dividido en 42 fragmentos.
# [19:20:03] DEBUG: Documento 2628 dividido en 21 fragmentos.
# [19:20:03] DEBUG: Documento 2629 dividido en 14 fragmentos.
# [19:20:03] DEBUG: Documento 2630 dividido en 22 fragmentos.
# [19:20:03] DEBUG: Documento 2631 dividido en 44 fragmentos.
# [19:20:03] DEBUG: Documento 2632 dividido en 54 fragmentos.
# [19:20:03] DEBUG: Documento 2633 dividido en 46 fragmentos.
# [19:20:03] DEBUG: Documento 2634 dividido en 22 fragmentos.
# [19:20:03] DEBUG: Documento 2635 dividido en 8 fragmentos.
# [19:20:03] DEBUG: Documento 2636 dividido en 7 fragmentos.
# [19:20:03] DEBUG: Documento 2637 dividido en 28 fragmentos.
# [19:20:03] DEBUG: Documento 2638 dividido en 67 fragmentos.
# [19:20:03] DEBUG: Documento 2639 dividido en 37 fragmentos.
# [19:20:03] DEBUG: Documento 2640 dividido en 39 fragmentos.
# [19:20:03] DEBUG: Documento 2641 dividido en 42 fragmentos.
# [19:20:03] DEBUG: Documento 2642 dividido en 52 fragmentos.
# [19:20:03] DEBUG: Documento 2643 dividido en 32 fragmentos.
# [19:20:03] DEBUG: Documento 2644 dividido en 38 fragmentos.
# [19:20:03] DEBUG: Documento 2645 dividido en 33 fragmentos.
# [19:20:03] DEBUG: Documento 2646 dividido en 51 fragmentos.
# [19:20:03] DEBUG: Documento 2647 dividido en 34 fragmentos.
# [19:20:03] DEBUG: Documento 2648 dividido en 30 fragmentos.
# [19:20:03] DEBUG: Documento 2649 dividido en 13 fragmentos.
# [19:20:03] DEBUG: Documento 2650 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2651 dividido en 58 fragmentos.
# [19:20:04] DEBUG: Documento 2652 dividido en 33 fragmentos.
# [19:20:04] DEBUG: Documento 2653 dividido en 17 fragmentos.
# [19:20:04] DEBUG: Documento 2654 dividido en 62 fragmentos.
# [19:20:04] DEBUG: Documento 2655 dividido en 40 fragmentos.
# [19:20:04] DEBUG: Documento 2656 dividido en 48 fragmentos.
# [19:20:04] DEBUG: Documento 2657 dividido en 36 fragmentos.
# [19:20:04] DEBUG: Documento 2658 dividido en 42 fragmentos.
# [19:20:04] DEBUG: Documento 2659 dividido en 60 fragmentos.
# [19:20:04] DEBUG: Documento 2660 dividido en 18 fragmentos.
# [19:20:04] DEBUG: Documento 2661 dividido en 46 fragmentos.
# [19:20:04] DEBUG: Documento 2662 dividido en 11 fragmentos.
# [19:20:04] DEBUG: Documento 2663 dividido en 14 fragmentos.
# [19:20:04] DEBUG: Documento 2664 dividido en 27 fragmentos.
# [19:20:04] DEBUG: Documento 2665 dividido en 25 fragmentos.
# [19:20:04] DEBUG: Documento 2666 dividido en 5 fragmentos.
# [19:20:04] DEBUG: Documento 2667 dividido en 57 fragmentos.
# [19:20:04] DEBUG: Documento 2668 dividido en 39 fragmentos.
# [19:20:04] DEBUG: Documento 2669 dividido en 52 fragmentos.
# [19:20:04] DEBUG: Documento 2670 dividido en 37 fragmentos.
# [19:20:04] DEBUG: Documento 2671 dividido en 38 fragmentos.
# [19:20:04] DEBUG: Documento 2672 dividido en 8 fragmentos.
# [19:20:04] DEBUG: Documento 2673 dividido en 48 fragmentos.
# [19:20:04] DEBUG: Documento 2674 dividido en 37 fragmentos.
# [19:20:04] DEBUG: Documento 2675 dividido en 61 fragmentos.
# [19:20:04] DEBUG: Documento 2676 dividido en 46 fragmentos.
# [19:20:04] DEBUG: Documento 2677 dividido en 46 fragmentos.
# [19:20:04] DEBUG: Documento 2678 dividido en 91 fragmentos.
# [19:20:04] DEBUG: Documento 2679 dividido en 33 fragmentos.
# [19:20:04] DEBUG: Documento 2680 dividido en 46 fragmentos.
# [19:20:04] DEBUG: Documento 2681 dividido en 55 fragmentos.
# [19:20:04] DEBUG: Documento 2682 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2683 dividido en 59 fragmentos.
# [19:20:04] DEBUG: Documento 2684 dividido en 24 fragmentos.
# [19:20:04] DEBUG: Documento 2685 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2686 dividido en 35 fragmentos.
# [19:20:04] DEBUG: Documento 2687 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2688 dividido en 37 fragmentos.
# [19:20:04] DEBUG: Documento 2689 dividido en 7 fragmentos.
# [19:20:04] DEBUG: Documento 2690 dividido en 5 fragmentos.
# [19:20:04] DEBUG: Documento 2691 dividido en 262 fragmentos.
# [19:20:04] DEBUG: Documento 2692 dividido en 262 fragmentos.
# [19:20:04] DEBUG: Documento 2693 dividido en 83 fragmentos.
# [19:20:04] DEBUG: Documento 2694 dividido en 17 fragmentos.
# [19:20:04] DEBUG: Documento 2695 dividido en 44 fragmentos.
# [19:20:04] DEBUG: Documento 2696 dividido en 11 fragmentos.
# [19:20:04] DEBUG: Documento 2697 dividido en 33 fragmentos.
# [19:20:04] DEBUG: Documento 2698 dividido en 45 fragmentos.
# [19:20:04] DEBUG: Documento 2699 dividido en 44 fragmentos.
# [19:20:04] DEBUG: Documento 2700 dividido en 35 fragmentos.
# [19:20:04] DEBUG: Documento 2701 dividido en 53 fragmentos.
# [19:20:04] DEBUG: Documento 2702 dividido en 34 fragmentos.
# [19:20:04] DEBUG: Documento 2703 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2704 dividido en 138 fragmentos.
# [19:20:04] DEBUG: Documento 2705 dividido en 43 fragmentos.
# [19:20:04] DEBUG: Documento 2706 dividido en 28 fragmentos.
# [19:20:04] DEBUG: Documento 2707 dividido en 10 fragmentos.
# [19:20:04] DEBUG: Documento 2708 dividido en 29 fragmentos.
# [19:20:04] DEBUG: Documento 2709 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2710 dividido en 32 fragmentos.
# [19:20:04] DEBUG: Documento 2711 dividido en 44 fragmentos.
# [19:20:04] DEBUG: Documento 2712 dividido en 5 fragmentos.
# [19:20:04] DEBUG: Documento 2713 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2714 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2715 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2716 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2717 dividido en 4 fragmentos.
# [19:20:04] DEBUG: Documento 2718 dividido en 4 fragmentos.
# [19:20:04] DEBUG: Documento 2719 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2720 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2721 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2722 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2723 dividido en 4 fragmentos.
# [19:20:04] DEBUG: Documento 2724 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2725 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2726 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2727 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2728 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2729 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2730 dividido en 5 fragmentos.
# [19:20:04] DEBUG: Documento 2731 dividido en 5 fragmentos.
# [19:20:04] DEBUG: Documento 2732 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2733 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2734 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2735 dividido en 4 fragmentos.
# [19:20:04] DEBUG: Documento 2736 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2737 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2738 dividido en 1 fragmentos.
# [19:20:04] DEBUG: Documento 2739 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2740 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2741 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2742 dividido en 5 fragmentos.
# [19:20:04] DEBUG: Documento 2743 dividido en 5 fragmentos.
# [19:20:04] DEBUG: Documento 2744 dividido en 37 fragmentos.
# [19:20:04] DEBUG: Documento 2745 dividido en 49 fragmentos.
# [19:20:04] DEBUG: Documento 2746 dividido en 36 fragmentos.
# [19:20:04] DEBUG: Documento 2747 dividido en 7 fragmentos.
# [19:20:04] DEBUG: Documento 2748 dividido en 7 fragmentos.
# [19:20:04] DEBUG: Documento 2749 dividido en 69 fragmentos.
# [19:20:04] DEBUG: Documento 2750 dividido en 18 fragmentos.
# [19:20:04] DEBUG: Documento 2751 dividido en 32 fragmentos.
# [19:20:04] DEBUG: Documento 2752 dividido en 27 fragmentos.
# [19:20:04] DEBUG: Documento 2753 dividido en 19 fragmentos.
# [19:20:04] DEBUG: Documento 2754 dividido en 4 fragmentos.
# [19:20:04] DEBUG: Documento 2755 dividido en 9 fragmentos.
# [19:20:04] DEBUG: Documento 2756 dividido en 6 fragmentos.
# [19:20:04] DEBUG: Documento 2757 dividido en 7 fragmentos.
# [19:20:04] DEBUG: Documento 2758 dividido en 7 fragmentos.
# [19:20:04] DEBUG: Documento 2759 dividido en 28 fragmentos.
# [19:20:04] DEBUG: Documento 2760 dividido en 71 fragmentos.
# [19:20:04] DEBUG: Documento 2761 dividido en 19 fragmentos.
# [19:20:04] DEBUG: Documento 2762 dividido en 36 fragmentos.
# [19:20:04] DEBUG: Documento 2763 dividido en 13 fragmentos.
# [19:20:04] DEBUG: Documento 2764 dividido en 455 fragmentos.
# [19:20:04] DEBUG: Documento 2765 dividido en 13 fragmentos.
# [19:20:04] DEBUG: Documento 2766 dividido en 69 fragmentos.
# [19:20:04] DEBUG: Documento 2767 dividido en 204 fragmentos.
# [19:20:04] DEBUG: Documento 2768 dividido en 30 fragmentos.
# [19:20:04] DEBUG: Documento 2769 dividido en 82 fragmentos.
# [19:20:04] DEBUG: Documento 2770 dividido en 80 fragmentos.
# [19:20:04] DEBUG: Documento 2771 dividido en 27 fragmentos.
# [19:20:04] DEBUG: Documento 2772 dividido en 40 fragmentos.
# [19:20:04] DEBUG: Documento 2773 dividido en 50 fragmentos.
# [19:20:04] DEBUG: Documento 2774 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2775 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2776 dividido en 68 fragmentos.
# [19:20:04] DEBUG: Documento 2777 dividido en 87 fragmentos.
# [19:20:04] DEBUG: Documento 2778 dividido en 43 fragmentos.
# [19:20:04] DEBUG: Documento 2779 dividido en 10 fragmentos.
# [19:20:04] DEBUG: Documento 2780 dividido en 71 fragmentos.
# [19:20:04] DEBUG: Documento 2781 dividido en 21 fragmentos.
# [19:20:04] DEBUG: Documento 2782 dividido en 8 fragmentos.
# [19:20:04] DEBUG: Documento 2783 dividido en 18 fragmentos.
# [19:20:04] DEBUG: Documento 2784 dividido en 34 fragmentos.
# [19:20:04] DEBUG: Documento 2785 dividido en 94 fragmentos.
# [19:20:04] DEBUG: Documento 2786 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2787 dividido en 47 fragmentos.
# [19:20:04] DEBUG: Documento 2788 dividido en 49 fragmentos.
# [19:20:04] DEBUG: Documento 2789 dividido en 3 fragmentos.
# [19:20:04] DEBUG: Documento 2790 dividido en 56 fragmentos.
# [19:20:04] DEBUG: Documento 2791 dividido en 54 fragmentos.
# [19:20:04] DEBUG: Documento 2792 dividido en 80 fragmentos.
# [19:20:04] DEBUG: Documento 2793 dividido en 11 fragmentos.
# [19:20:04] DEBUG: Documento 2794 dividido en 94 fragmentos.
# [19:20:04] DEBUG: Documento 2795 dividido en 5 fragmentos.
# [19:20:04] DEBUG: Documento 2796 dividido en 55 fragmentos.
# [19:20:04] DEBUG: Documento 2797 dividido en 3 fragmentos.
# [19:20:05] DEBUG: Documento 2798 dividido en 12 fragmentos.
# [19:20:05] DEBUG: Documento 2799 dividido en 37 fragmentos.
# [19:20:05] DEBUG: Documento 2800 dividido en 52 fragmentos.
# [19:20:05] DEBUG: Documento 2801 dividido en 41 fragmentos.
# [19:20:05] DEBUG: Documento 2802 dividido en 11 fragmentos.
# [19:20:05] DEBUG: Documento 2803 dividido en 6 fragmentos.
# [19:20:05] DEBUG: Documento 2804 dividido en 4 fragmentos.
# [19:20:05] DEBUG: Documento 2805 dividido en 10 fragmentos.
# [19:20:05] DEBUG: Documento 2806 dividido en 56 fragmentos.
# [19:20:05] DEBUG: Documento 2807 dividido en 9 fragmentos.
# [19:20:05] DEBUG: Documento 2808 dividido en 42 fragmentos.
# [19:20:05] DEBUG: Documento 2809 dividido en 33 fragmentos.
# [19:20:05] DEBUG: Documento 2810 dividido en 61 fragmentos.
# [19:20:05] DEBUG: Documento 2811 dividido en 71 fragmentos.
# [19:20:05] DEBUG: Documento 2812 dividido en 10 fragmentos.
# [19:20:05] DEBUG: Documento 2813 dividido en 46 fragmentos.
# [19:20:05] DEBUG: Documento 2814 dividido en 43 fragmentos.
# [19:20:05] DEBUG: Documento 2815 dividido en 4 fragmentos.
# [19:20:05] DEBUG: Documento 2816 dividido en 3 fragmentos.
# [19:20:05] DEBUG: Documento 2817 dividido en 4 fragmentos.
# [19:20:05] DEBUG: Documento 2818 dividido en 4 fragmentos.
# [19:20:05] DEBUG: Documento 2819 dividido en 1 fragmentos.
# [19:20:05] DEBUG: Documento 2820 dividido en 4 fragmentos.
# [19:20:05] DEBUG: Documento 2821 dividido en 4 fragmentos.
# [19:20:05] DEBUG: Documento 2822 dividido en 4 fragmentos.
# [19:20:05] DEBUG: Documento 2823 dividido en 4 fragmentos.
# [19:20:05] DEBUG: Documento 2824 dividido en 1 fragmentos.
# [19:20:05] DEBUG: Documento 2825 dividido en 1 fragmentos.
# [19:20:05] DEBUG: Documento 2826 dividido en 3 fragmentos.
# [19:20:05] DEBUG: Documento 2827 dividido en 56 fragmentos.
# [19:20:05] DEBUG: Documento 2828 dividido en 32 fragmentos.
# [19:20:05] DEBUG: Documento 2829 dividido en 5 fragmentos.
# [19:20:05] DEBUG: Documento 2830 dividido en 8 fragmentos.
# [19:20:05] DEBUG: Documento 2831 dividido en 24 fragmentos.
# [19:20:05] DEBUG: Documento 2832 dividido en 9 fragmentos.
# [19:20:05] DEBUG: Documento 2833 dividido en 42 fragmentos.
# [19:20:05] DEBUG: Documento 2834 dividido en 1 fragmentos.
# [19:20:05] DEBUG: Documento 2835 dividido en 25 fragmentos.
# [19:20:05] INFO: Total de 91717 fragmentos creados.
# [19:20:05] INFO: Cargando modelo de embeddings HuggingFace...
# [19:20:05] INFO: Modelo de embeddings cargado correctamente.
# [19:20:05] INFO: Creando base vectorial con ChromaDB...
# [21:05:59] INFO: Guardando base vectorial en disco...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_7859/3031248963.py in <module>
#      55
#      56 print(f"[{time.strftime('%H:%M:%S')}] INFO: Guardando base vectorial en disco...")
# ---> 57 vector_db.persist()
#      58 print(f"[{time.strftime('%H:%M:%S')}] SUCCESS: Pipeline completado. Base vectorial guardada en './repositorio_vectorial'")
#
# AttributeError: 'Chroma' object has no attribute 'persist'

# %% [markdown]
# Ejemplo de recuperación de información en el repositorio vectorial

# %%
from langchain_chroma import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

# Cargar el repositorio existente
embed_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vector_db = Chroma(
    persist_directory="./repositorio_vectorial",
    embedding_function=embed_model
)

# Método 1: Obtener conteo de documentos
num_docs = vector_db._collection.count()
print(f"📊 Número total de fragmentos/documentos en la base: {num_docs}")

# Método 2: Obtener algunos documentos de ejemplo
sample_docs = vector_db._collection.get(limit=5)
print("\n🔍 Muestra de documentos almacenados:")
for i, (content, metadata) in enumerate(zip(sample_docs['documents'], sample_docs['metadatas'])):
    print(f"\nDocumento {i+1}:")
    print(f"ID: {sample_docs['ids'][i]}")
    print(f"Título: {metadata.get('titulo', 'N/A')}")
    print(f"Fragmento ID: {metadata.get('fragmento_id', 'N/A')}")
    print(f"Contenido (inicio): {content[:200]}...")
# Out:
# 📊 Número total de fragmentos/documentos en la base: 91717
#
# 🔍 Muestra de documentos almacenados:
#
# Documento 1:
# ID: 3d37af8d-5c5d-4f1b-9e79-48b50a0d7c8e
# Título: Machine Learning Algorithm in Agricultural Machine Vision System
# Fragmento ID: 10.38007/ml.2020.010404_part1
# Contenido (inicio): scholar publishing group machine learn ing theory and practice httpsdoiorg ml issn v ol issue copyright by the authors this is an open access article distributed under the creative commons attribution...
#
# Documento 2:
# ID: 4d65ee27-83a2-4411-a5e3-af4a2d104bd4
# Título: Machine Learning Algorithm in Agricultural Machine Vision System
# Fragmento ID: 10.38007/ml.2020.010404_part2
# Contenido (inicio): key technologies and machine learning algorithms of agricultural machine vision system and briefly discusses the syste m hardware selection and software development environment for the application of ...
#
# Documento 3:
# ID: 96a79488-92b8-41b5-8fb6-52128c9efb25
# Título: Machine Learning Algorithm in Agricultural Machine Vision System
# Fragmento ID: 10.38007/ml.2020.010404_part3
# Contenido (inicio): machine vision system means that it can work automatically without human intervention it can judge and solve problems i ndependently according to the changes of farming make agricultural machinery wor...
#
# Documento 4:
# ID: 659446aa-fa83-4cb7-a1c5-85eb09a4544c
# Título: Machine Learning Algorithm in Agricultural Machine Vision System
# Fragmento ID: 10.38007/ml.2020.010404_part4
# Contenido (inicio): to better distinguish seedlings and residues the rgb method and the previous ex gotsu method are used to visually compare their performance the segmentation qu ality factor and time consumption are us...
#
# Documento 5:
# ID: 9c02fabd-c84f-4d06-99b1-2761cccdf816
# Título: Machine Learning Algorithm in Agricultural Machine Vision System
# Fragmento ID: 10.38007/ml.2020.010404_part5
# Contenido (inicio): video processing algorithm with graphics processing unit gpu for the post harvest stage the final accuracy of each system is and bill studied an automatic monitoring system for rice light trap pests b...
